# %% [markdown]
# # Data inspection for rt_trips_DB_2018
#
# As per the Concept Design Extract:
# - Each record of this table contains the actual data for one trip.
# - If the trip is planned and achieved, the record will contain both the planned and actual data.
# - If the tripped is planned and suppressed the record will contain only the planned data and the flag “Suppressed” will be checked.
# - If the trips is partially suppressed the flag “Suppressed” will not be checked. The set of the leave
# - times suppressed is detailed in table RT_LeaveTimes ( 9.2.3 ).
# - Each record could be referred to a fault event by using the field “JustificationID”.

# %% [markdown]
# #### Import Necessary Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta, date

# %% [markdown]
# #### Read in trips file

# %%
df = pd.read_csv("~/data/Data_Files/rt_trips_DB_2018.txt", delimiter = ';')

# %%
df.loc[df['LINEID']== '41D'].shape
# Out:
# (36, 16)

# %% [markdown]
# The file is large-

# %%
df.shape
# Out:
# (2182637, 16)

# %%
df.columns
# Out:
# Index(['DATASOURCE', 'DAYOFSERVICE', 'TRIPID', 'LINEID', 'ROUTEID',
#        'DIRECTION', 'PLANNEDTIME_ARR', 'PLANNEDTIME_DEP', 'ACTUALTIME_ARR',
#        'ACTUALTIME_DEP', 'BASIN', 'TENDERLOT', 'SUPPRESSED', 'JUSTIFICATIONID',
#        'LASTUPDATE', 'NOTE'],
#       dtype='object')

# %%
# remove any whitespaces in the column names
df.columns = df.columns.str.replace(' ', '')

# %% [markdown]
# #### Convert features to appropriate datatypes

# %%
df.dtypes
# Out:
# DATASOURCE          object
# DAYOFSERVICE        object
# TRIPID               int64
# LINEID              object
# ROUTEID             object
# DIRECTION            int64
# PLANNEDTIME_ARR      int64
# PLANNEDTIME_DEP      int64
# ACTUALTIME_ARR     float64
# ACTUALTIME_DEP     float64
# BASIN               object
# TENDERLOT          float64
# SUPPRESSED         float64
# JUSTIFICATIONID    float64
# LASTUPDATE          object
# NOTE                object
# dtype: object

# %% [markdown]
# __Examing the data we will now convert columns into their appropriate types__
#
# - **Datasource** is categorical as it is a defined as"DB" for Dublin Bus
# - **Day of Service** is a date and thus will be converted as such
# - **TripID** is categorical as it is a label for trips and thus does make sense to asses in a continous manner
# - **LineID  & RouteID** are also categorical as it corresponds to the bus line which is a set number
# - **Direction** is categorical as it is either inbound or outbound
# - **PlannedTime_Dep, PlannedTime_Arr and ActualTime_Dep, ActualTime_Arr** - continous data representing trip time in seconds
# - **Basin, Tenderlot, Suprressed, Justification and Note** - All categorical
# - **LastUpdate** - datetime

# %% [markdown]
# __Continous Columns will be converted to float32 for memory preservation__

# %%
cat_cols = ['DATASOURCE', 'TRIPID', 'LINEID', 'ROUTEID', 'DIRECTION','BASIN', 'TENDERLOT', 'SUPPRESSED', 'JUSTIFICATIONID','NOTE']
cont_cols = ['PLANNEDTIME_ARR', 'PLANNEDTIME_DEP', 'ACTUALTIME_ARR',
       'ACTUALTIME_DEP']
for column in cont_cols:
    df[column]= df[column].astype('float32')
    
for column in cat_cols:   
     df[column]= df[column].astype('category')
        
date_time=['DAYOFSERVICE','LASTUPDATE']  
df[date_time]=df[date_time].apply(pd.to_datetime)

# %%
df.dtypes
# Out:
# DATASOURCE               category
# DAYOFSERVICE       datetime64[ns]
# TRIPID                   category
# LINEID                   category
# ROUTEID                  category
# DIRECTION                category
# PLANNEDTIME_ARR           float32
# PLANNEDTIME_DEP           float32
# ACTUALTIME_ARR            float32
# ACTUALTIME_DEP            float32
# BASIN                    category
# TENDERLOT                category
# SUPPRESSED               category
# JUSTIFICATIONID          category
# LASTUPDATE         datetime64[ns]
# NOTE                     category
# dtype: object

# %% [markdown]
# ### Check for duplicates

# %%
#Print the number of duplicates, without the original rows that were duplicated
print('Number of duplicate (excluding first) rows in the table is: ', df.duplicated().sum())

# Check for duplicate rows. 
# Use "keep=False" to mark all duplicates as true, including the original rows that were duplicated.
print('Number of duplicate rows (including first) in the table is:', df[df.duplicated(keep=False)].shape[0])
# Out:
# Number of duplicate (excluding first) rows in the table is:  0
# Number of duplicate rows (including first) in the table is: 0

# %% [markdown]
# **No Duplicates found**

# %% [markdown]
# ## Continous Statistics will be evaluated below

# %%
df.describe(datetime_is_numeric=True).T
# Out:
#                      count                           mean  \
# DAYOFSERVICE       2182637  2018-06-28 17:25:38.969786880
# PLANNEDTIME_ARR  2182637.0                   55078.746094
# PLANNEDTIME_DEP  2182637.0                   51533.277344
# ACTUALTIME_ARR   2045430.0                   55062.398438
# ACTUALTIME_DEP   2018086.0                      51706.125
# LASTUPDATE         2182637  2018-07-16 10:25:44.996667392
#
#                                  min                  25%  \
# DAYOFSERVICE     2018-01-01 00:00:00  2018-03-31 00:00:00
# PLANNEDTIME_ARR              18203.0              39683.0
# PLANNEDTIME_DEP              16200.0              36000.0
# ACTUALTIME_ARR               17546.0              39668.0
# ACTUALTIME_DEP               15974.0              36518.0
# LASTUPDATE       2018-01-08 17:21:10  2018-04-10 15:08:12
#
#                                  50%                  75%  \
# DAYOFSERVICE     2018-06-28 00:00:00  2018-09-26 00:00:00
# PLANNEDTIME_ARR              55276.0              69006.0
# PLANNEDTIME_DEP              51600.0              65160.0
# ACTUALTIME_ARR               55189.0              69019.0
# ACTUALTIME_DEP               51618.0              65398.0
# LASTUPDATE       2018-07-13 19:47:00  2018-10-23 06:57:21
#
#                                  max           std
# DAYOFSERVICE     2018-12-31 00:00:00           NaN
# PLANNEDTIME_ARR              91680.0  17424.822266
# PLANNEDTIME_DEP              87600.0  17571.636719
# ACTUALTIME_ARR               94378.0  17338.699219
# ACTUALTIME_DEP               97177.0  17526.949219
# LASTUPDATE       2019-01-16 18:27:21           NaN

# %% [markdown]
# __Three constant columns can be seen in Datasource, Basin, Tenderlot and Suppressed__
#
# - They will ned to be removed as they cannot provide insight into the problem domain.

# %%
df.select_dtypes(['category']).describe().T
# Out:
#                    count  unique        top     freq
# DATASOURCE       2182637       1         DB  2182637
# TRIPID           2182637  658964    7327038       19
# LINEID           2182637     130        46A    76728
# ROUTEID          2182637     588     46A_74    37182
# DIRECTION        2182637       2          2  1100273
# BASIN            2182637       1     BasDef  2182637
# TENDERLOT              0       0        NaN      NaN
# SUPPRESSED        4333.0     1.0        0.0   4333.0
# JUSTIFICATIONID   4330.0  3526.0   203708.0     19.0
# NOTE             2182637   46690  ,2703274,      244

# %% [markdown]
# ## Check for Missing Values

# %% [markdown]
# - Thankfully, the majority of missing values are in the columns with constant values and therefore do not affect the features that could provide insight into the problem domain.

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)*100
# Out:
# TENDERLOT          100.000000
# JUSTIFICATIONID     99.801616
# SUPPRESSED          99.801479
# ACTUALTIME_DEP       7.539091
# ACTUALTIME_ARR       6.286295
# DATASOURCE           0.000000
# DAYOFSERVICE         0.000000
# TRIPID               0.000000
# LINEID               0.000000
# ROUTEID              0.000000
# DIRECTION            0.000000
# PLANNEDTIME_ARR      0.000000
# PLANNEDTIME_DEP      0.000000
# BASIN                0.000000
# LASTUPDATE           0.000000
# NOTE                 0.000000
# dtype: float64

# %%
df.head()
# Out:
#   DATASOURCE DAYOFSERVICE   TRIPID LINEID  ROUTEID DIRECTION  PLANNEDTIME_ARR  \
# 0         DB   2018-02-07  6253783     68    68_80         1          87245.0
# 1         DB   2018-02-07  6262138    25B  25B_271         2          30517.0
# 2         DB   2018-02-07  6254942    45A   45A_70         2          35512.0
# 3         DB   2018-02-07  6259460    25A  25A_273         1          57261.0
# 4         DB   2018-02-07  6253175     14    14_15         1          85383.0
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN TENDERLOT  \
# 0          84600.0         87524.0         84600.0  BasDef       NaN
# 1          26460.0         32752.0             NaN  BasDef       NaN
# 2          32100.0         36329.0         32082.0  BasDef       NaN
# 3          54420.0         58463.0         54443.0  BasDef       NaN
# 4          81600.0         84682.0         81608.0  BasDef       NaN
#
#   SUPPRESSED JUSTIFICATIONID          LASTUPDATE       NOTE
# 0        NaN             NaN 2018-02-28 12:05:11  ,2967409,
# 1        NaN             NaN 2018-02-28 12:05:11  ,2580260,
# 2        NaN             NaN 2018-02-28 12:05:11  ,2448968,
# 3        NaN             NaN 2018-02-28 12:05:11  ,3094242,
# 4        NaN             NaN 2018-02-28 12:05:11  ,2526331,

# %%
continuous_columns = df.select_dtypes([ 'float32']).columns
df[continuous_columns].describe().T
# Out:
#                      count          mean           std      min      25%  \
# PLANNEDTIME_ARR  2182637.0  55078.746094  17424.822266  18203.0  39683.0
# PLANNEDTIME_DEP  2182637.0  51533.277344  17571.636719  16200.0  36000.0
# ACTUALTIME_ARR   2045430.0  55062.398438  17338.699219  17546.0  39668.0
# ACTUALTIME_DEP   2018086.0  51706.125000  17526.949219  15974.0  36518.0
#
#                      50%      75%      max
# PLANNEDTIME_ARR  55276.0  69006.0  91680.0
# PLANNEDTIME_DEP  51600.0  65160.0  87600.0
# ACTUALTIME_ARR   55189.0  69019.0  94378.0
# ACTUALTIME_DEP   51618.0  65398.0  97177.0

# %%
categorical_columns = df.select_dtypes(['category']).columns
df[categorical_columns].describe().T
# Out:
#                    count  unique        top     freq
# DATASOURCE       2182637       1         DB  2182637
# TRIPID           2182637  658964    7327038       19
# LINEID           2182637     130        46A    76728
# ROUTEID          2182637     588     46A_74    37182
# DIRECTION        2182637       2          2  1100273
# BASIN            2182637       1     BasDef  2182637
# TENDERLOT              0       0        NaN      NaN
# SUPPRESSED        4333.0     1.0        0.0   4333.0
# JUSTIFICATIONID   4330.0  3526.0   203708.0     19.0
# NOTE             2182637   46690  ,2703274,      244

# %%
df
# Out:
#         DATASOURCE DAYOFSERVICE   TRIPID LINEID  ROUTEID DIRECTION  \
# 0               DB   2018-02-07  6253783     68    68_80         1
# 1               DB   2018-02-07  6262138    25B  25B_271         2
# 2               DB   2018-02-07  6254942    45A   45A_70         2
# 3               DB   2018-02-07  6259460    25A  25A_273         1
# 4               DB   2018-02-07  6253175     14    14_15         1
# ...            ...          ...      ...    ...      ...       ...
# 2182632         DB   2018-05-14  6765849    123   123_36         2
# 2182633         DB   2018-05-14  6765469     75    75_17         1
# 2182634         DB   2018-05-14  6765486    33D   33D_62         2
# 2182635         DB   2018-05-14  6764987     70    70_60         1
# 2182636         DB   2018-05-14  6765012     27    27_19         1
#
#          PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# 0                87245.0          84600.0         87524.0         84600.0
# 1                30517.0          26460.0         32752.0             NaN
# 2                35512.0          32100.0         36329.0         32082.0
# 3                57261.0          54420.0         58463.0         54443.0
# 4                85383.0          81600.0         84682.0         81608.0
# ...                  ...              ...             ...             ...
# 2182632          61560.0          57840.0         61365.0         57859.0
# 2182633          53416.0          48600.0             NaN         48823.0
# 2182634          29460.0          26400.0         29904.0             NaN
# 2182635          65277.0          60600.0         66341.0             NaN
# 2182636          47722.0          41700.0         47508.0         41642.0
#
#           BASIN TENDERLOT SUPPRESSED JUSTIFICATIONID          LASTUPDATE  \
# 0        BasDef       NaN        NaN             NaN 2018-02-28 12:05:11
# 1        BasDef       NaN        NaN             NaN 2018-02-28 12:05:11
# 2        BasDef       NaN        NaN             NaN 2018-02-28 12:05:11
# 3        BasDef       NaN        NaN             NaN 2018-02-28 12:05:11
# 4        BasDef       NaN        NaN             NaN 2018-02-28 12:05:11
# ...         ...       ...        ...             ...                 ...
# 2182632  BasDef       NaN        NaN             NaN 2018-06-26 09:13:13
# 2182633  BasDef       NaN        NaN             NaN 2018-06-26 09:13:13
# 2182634  BasDef       NaN        NaN             NaN 2018-06-26 09:13:13
# 2182635  BasDef       NaN        NaN             NaN 2018-06-26 09:13:13
# 2182636  BasDef       NaN        NaN             NaN 2018-06-26 09:13:13
#
#               NOTE
# 0        ,2967409,
# 1        ,2580260,
# 2        ,2448968,
# 3        ,3094242,
# 4        ,2526331,
# ...            ...
# 2182632  ,3216350,
# 2182633  ,2865284,
# 2182634  ,3077688,
# 2182635  ,3208841,
# 2182636  ,2960092,
#
# [2182637 rows x 16 columns]

# %% [markdown]
# # Data Quality Plan

# %% [markdown]
# - DATASOURCE - constant - delete
# - DAYOFSERVICE - converted to datetime
# - TRIPID - convert to category
# - LINEID categorical
# - STOPPOINTID - convert to category
# - PLANNEDTIME_ARR PLANNEDTIME_DEP ACTUALTIME_ARR ACTUALTIME_DEP VEHICLEID - category
# - DIRECTION - categorical IB inbound = north/east, OB= outbound/south/wedt
# - TENDERLOT - missing vals - delete
# - BASIN - missing vals - delete
# - SUPRESSED - missing vals - delete
# - JUSTIFICATION - missing vals - delete
# - LASTUPDATE  - delete
# - NOTE - not enough information to use - delete

# %%
del df['NOTE']
del df['LASTUPDATE']
del df['JUSTIFICATIONID']
del df['SUPPRESSED']
del df['BASIN']
del df['TENDERLOT']
del df['DATASOURCE']

# %%
df
# Out:
#         DAYOFSERVICE   TRIPID LINEID  ROUTEID DIRECTION  PLANNEDTIME_ARR  \
# 0         2018-02-07  6253783     68    68_80         1          87245.0
# 1         2018-02-07  6262138    25B  25B_271         2          30517.0
# 2         2018-02-07  6254942    45A   45A_70         2          35512.0
# 3         2018-02-07  6259460    25A  25A_273         1          57261.0
# 4         2018-02-07  6253175     14    14_15         1          85383.0
# ...              ...      ...    ...      ...       ...              ...
# 2182632   2018-05-14  6765849    123   123_36         2          61560.0
# 2182633   2018-05-14  6765469     75    75_17         1          53416.0
# 2182634   2018-05-14  6765486    33D   33D_62         2          29460.0
# 2182635   2018-05-14  6764987     70    70_60         1          65277.0
# 2182636   2018-05-14  6765012     27    27_19         1          47722.0
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP
# 0                84600.0         87524.0         84600.0
# 1                26460.0         32752.0             NaN
# 2                32100.0         36329.0         32082.0
# 3                54420.0         58463.0         54443.0
# 4                81600.0         84682.0         81608.0
# ...                  ...             ...             ...
# 2182632          57840.0         61365.0         57859.0
# 2182633          48600.0             NaN         48823.0
# 2182634          26400.0         29904.0             NaN
# 2182635          60600.0         66341.0             NaN
# 2182636          41700.0         47508.0         41642.0
#
# [2182637 rows x 9 columns]

# %%
df['JourneyLengthMINS']= (df['ACTUALTIME_ARR']-df['ACTUALTIME_DEP'])/60

# %%
df['PlannedLengthMINS']= (df['PLANNEDTIME_ARR']-df['PLANNEDTIME_DEP'])/60

# %%
df
# Out:
#         DAYOFSERVICE   TRIPID LINEID  ROUTEID DIRECTION  PLANNEDTIME_ARR  \
# 0         2018-02-07  6253783     68    68_80         1          87245.0
# 1         2018-02-07  6262138    25B  25B_271         2          30517.0
# 2         2018-02-07  6254942    45A   45A_70         2          35512.0
# 3         2018-02-07  6259460    25A  25A_273         1          57261.0
# 4         2018-02-07  6253175     14    14_15         1          85383.0
# ...              ...      ...    ...      ...       ...              ...
# 2182632   2018-05-14  6765849    123   123_36         2          61560.0
# 2182633   2018-05-14  6765469     75    75_17         1          53416.0
# 2182634   2018-05-14  6765486    33D   33D_62         2          29460.0
# 2182635   2018-05-14  6764987     70    70_60         1          65277.0
# 2182636   2018-05-14  6765012     27    27_19         1          47722.0
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  JourneyLengthMINS  \
# 0                84600.0         87524.0         84600.0          48.733334
# 1                26460.0         32752.0             NaN                NaN
# 2                32100.0         36329.0         32082.0          70.783333
# 3                54420.0         58463.0         54443.0          67.000000
# 4                81600.0         84682.0         81608.0          51.233334
# ...                  ...             ...             ...                ...
# 2182632          57840.0         61365.0         57859.0          58.433334
# 2182633          48600.0             NaN         48823.0                NaN
# 2182634          26400.0         29904.0             NaN                NaN
# 2182635          60600.0         66341.0             NaN                NaN
# 2182636          41700.0         47508.0         41642.0          97.766670
#
#          PlannedLengthMINS
# 0                44.083332
# 1                67.616669
# 2                56.866665
# 3                47.349998
# 4                63.049999
# ...                    ...
# 2182632          62.000000
# 2182633          80.266670
# 2182634          51.000000
# 2182635          77.949997
# 2182636         100.366669
#
# [2182637 rows x 11 columns]

# %%
List_Routes = list(df['LINEID'].unique())
len(List_Routes)
# Out:
# 130

# %%
# df.to_csv("Cleaned_Trips_2018.csv", index=False)

# %%
# import sqlite3
# conn = sqlite3.connect("leave_times_2018.sqlite")
# df.to_sql(name='Cleaned_Trips_final', con=conn)

# %%
# p2 = pd.read_sql('select * from Cleaned_Trips_final', conn)
# p2

# %%
df['JourneyTimeDiff']= (df['JourneyLengthMINS']-df['PlannedLengthMINS'])

# %%
df['EarlyOrLate']=  ['Early' if x < 0 else "Late" for x in df['JourneyTimeDiff']]

# %%
df.loc[df['LINEID'] == "46A"]
# Out:
#         DAYOFSERVICE   TRIPID LINEID ROUTEID DIRECTION  JourneyLengthMINS  \
# 15        2018-02-07  6253924    46A  46A_74         1          85.816666
# 20        2018-02-07  6262164    46A  46A_74         1          82.666664
# 88        2018-02-18  6265839    46A  46A_67         2          67.866669
# 89        2018-02-18  6279639    46A  46A_67         2          68.083336
# 90        2018-02-18  6276477    46A  46A_67         2          74.133331
# ...              ...      ...    ...     ...       ...                ...
# 2182408   2018-05-15  6756827    46A  46A_67         2          62.000000
# 2182413   2018-05-15  6756837    46A  46A_67         2          53.783333
# 2182458   2018-05-15  6764906    46A  46A_74         1          68.699997
# 2182470   2018-05-15  6762038    46A  46A_74         1          96.633331
# 2182535   2018-05-14  6763192    46A  46A_74         1          78.000000
#
#          PlannedLengthMINS  JourneyTimeDiff EarlyOrLate
# 15               80.133331         5.683334        Late
# 20               73.283333         9.383331        Late
# 88               58.483334         9.383335        Late
# 89               58.483334         9.600002        Late
# 90               58.483334        15.649998        Late
# ...                    ...              ...         ...
# 2182408          54.483334         7.516666        Late
# 2182413          59.583332        -5.799999       Early
# 2182458          74.633331        -5.933334       Early
# 2182470          83.833336        12.799995        Late
# 2182535          83.833336        -5.833336       Early
#
# [76728 rows x 9 columns]

# %%
df['EarlyOrLate'].value_counts(normalize=True) * 100
# Out:
# Late     77.589173
# Early    22.410827
# Name: EarlyOrLate, dtype: float64
